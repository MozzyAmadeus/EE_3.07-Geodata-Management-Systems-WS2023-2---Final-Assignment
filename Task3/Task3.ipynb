# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     C:\Users\demid\anaconda3
# geo                   *  C:\Users\demid\anaconda3\envs\geo

# %%
import os
path = os.environ['PATH']
path
# Out:
# 'C:\\Users\\demid\\anaconda3\\envs\\geo;C:\\Users\\demid\\anaconda3\\envs\\geo\\Library\\mingw-w64\\bin;C:\\Users\\demid\\anaconda3\\envs\\geo\\Library\\usr\\bin;C:\\Users\\demid\\anaconda3\\envs\\geo\\Library\\bin;C:\\Users\\demid\\anaconda3\\envs\\geo\\Scripts;C:\\Users\\demid\\anaconda3\\envs\\geo\\bin;C:\\Users\\demid\\anaconda3\\condabin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Program Files\\dotnet;C:\\Users\\demid\\AppData\\Local\\Microsoft\\WindowsApps;.'

# %%
conda_prefix = os.environ['conda_prefix']
print(f"CONDA_PREFIX: {conda_prefix:s}")
os.environ['proj_lib'] = conda_prefix + r"\Library\share\proj"
proj_lib = os.environ['proj_lib']
print(f"New env var value: \nPROJ_LIB={proj_lib:s}")
# Out:
# CONDA_PREFIX: C:\Users\demid\anaconda3\envs\geo
# New env var value:
# PROJ_LIB=C:\Users\demid\anaconda3\envs\geo\Library\share\proj

# %%
import pandas as pd
import geopandas as gpd

# %%
data_in_dir = r"../GeoData_WS2023_2_Final_D/data/original/"
for elt in os.listdir(data_in_dir): print(elt)
# Out:
# DWD
# katalog_gemeinde.csv
# katalog_stoff.csv
# KL_Jahreswerte_Beschreibung_Stationen.txt
# opendata.gw_chemischer_messwert.csv
# opendata.gw_messstelle.csv

# %%
gw_station_fname = r"opendata.gw_messstelle.csv"
gw_station_pfname = data_in_dir + gw_station_fname
print(f"Stationsdaten:  {gw_station_pfname:s}")
# Out:
# Stationsdaten:  ../GeoInfo_WS2023_2_Final_D/data/original/opendata.gw_messstelle.csv

# %%
df = pd.read_csv(gw_station_pfname, sep = ";", index_col=["messstelle_id"])

# %%
df.sort_index(ascending=True, inplace=True)

# %%
num_total = df.shape[0]
df.shape
# Out:
# (71120, 38)

# %%
print(f"{pd.get_option('display.max_columns') = }")
pd.set_option("display.max_columns", None)
print(f"{pd.get_option('display.max_columns') = }")
# Out:
# pd.get_option('display.max_columns') = 20
# pd.get_option('display.max_columns') = None

# %%
df.head()
# Out:
#                sl_nr                         name     e32      n32  \
# messstelle_id
# 10000008       70796  P3-BSR/Mariaschacht P 5 neu  3068xx  56254xx
# 10000010           1          SCHERPENSEEL NR 1    2935xx  56452xx
# 10000021           2          Bellinghoven Nr. 2   312776  5660432
# 10000033           3          Doveren Nr. 3        3070xx  56583xx
# 10000045           4          Geilenkirchen Nr. 5  299399  5650595
#
#                gw_stockwerk grundstueck gemeinde_id gwhorizont_id  \
# messstelle_id
# 10000008                1.0                05334032           NaN
# 10000010                1.0      privat    05370028            6D
# 10000021                1.0      privat    05370004            14
# 10000033                1.0      privat    05370020            16
# 10000045                1.0      privat    05370012            10
#
#                                               gwhorizont gwleiter_id  \
# messstelle_id
# 10000008                                             NaN         NaN
# 10000010                                  Neurather Sand         NaN
# 10000021                           Ältere Hauptterrassen         NaN
# 10000033       Jüngere Hauptterrassen mit Lößauflagerung          Hj
# 10000045                                 Sande und Kiese         NaN
#
#                             gwleiter                 einrichtungsgrund  \
# messstelle_id
# 10000008                         NaN  GW-Beschaffenheit
# 10000010                         NaN  LGD
# 10000021                         NaN  LGD
# 10000033       Jüngere Hauptterrasse  LGD
# 10000045                         NaN  LGD
#
#               gwk_lage_auf_id gwk_lage_id gwk_monitoring_auf_id  \
# messstelle_id
# 10000008           01.07.2016      282_11            01.07.2016
# 10000010           01.07.2016       28_04            01.07.2016
# 10000021           01.07.2016      286_07            01.07.2016
# 10000033           01.07.2016      282_01            01.07.2016
# 10000045           01.07.2016      282_03            01.07.2016
#
#               gwk_monitoring_id                      messprogramm  \
# messstelle_id
# 10000008                 282_11  RWÜ (Messstelle f. GWÜ geeignet)
# 10000010                  28_04        Grundwassergüteüberwachung
# 10000021                 286_07                               NaN
# 10000033                 282_01      Emittentenmst./Anlagenüberw.
# 10000045                 282_03                               NaN
#
#                           turnus_wasserstand freigabe_wstd freigabe_chemie  \
# messstelle_id
# 10000008                           monatlich          nein            nein
# 10000010       Messstelle besteht nicht mehr            ja              ja
# 10000021                  Messstelle inaktiv            ja            nein
# 10000033                  Messstelle inaktiv            ja            nein
# 10000045       Messstelle besteht nicht mehr            ja            nein
#
#               freigabe_lage wasserstandsmessstelle guetemessstelle  \
# messstelle_id
# 10000008               nein                     ja              ja
# 10000010               nein                     ja              ja
# 10000021                 ja                     ja            nein
# 10000033               nein                     ja              ja
# 10000045                 ja                     ja            nein
#
#               im_wrrl_messnetz_chemie im_wrrl_messnetz_wasserstand  \
# messstelle_id
# 10000008                         nein                         nein
# 10000010                         nein                         nein
# 10000021                         nein                         nein
# 10000033                         nein                         nein
# 10000045                         nein                         nein
#
#                                  messstellenart     wasserart labor  \
# messstelle_id
# 10000008       GW-Messstelle                     keine Angabe     -
# 10000010       GW-Messstelle                     keine Angabe     -
# 10000021       Schachtbrunnen                             NaN   NaN
# 10000033       Schachtbrunnen                    keine Angabe     -
# 10000045                  Vertikalfilterbrunnen           NaN   NaN
#
#               beobachtung_wasserstand  \
# messstelle_id
# 10000008                            -
# 10000010                            -
# 10000021                            -
# 10000033                            -
# 10000045                            -
#
#                                                      eigentuemer  \
# messstelle_id
# 10000008       BSR Schotterwerk                              ...
# 10000010       Land NRW                                      ...
# 10000021       keine Angabe                                  ...
# 10000033       Privatperson                                  ...
# 10000045       Privatperson                                  ...
#
#                                                        betreiber  \
# messstelle_id
# 10000008       Enwor GmbH                                    ...
# 10000010       keine Angabe                                  ...
# 10000021       keine Angabe                                  ...
# 10000033       keine Angabe                                  ...
# 10000045       keine Angabe                                  ...
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 10000008                 700.0                 NaN                  80.0
# 10000010                 400.0                 NaN                 100.0
# 10000021                   NaN                 NaN                1000.0
# 10000033                   NaN                 NaN                1000.0
# 10000045                 200.0                 NaN                1000.0
#
#                historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 10000008                         NaN           1570.0              21053.0
# 10000010                         NaN           4936.0               7731.0
# 10000021                         NaN           1411.0               7885.0
# 10000033                         NaN            755.0               4847.0
# 10000045                         NaN           1079.0               6140.0
#
#                unterkante_filter_cm
# messstelle_id
# 10000008                    20353.0
# 10000010                     7331.0
# 10000021                     7885.0
# 10000033                     4847.0
# 10000045                     5940.0

# %%
df[df["grundstueck"]=="oeffentlich"].head()
# Out:
#                sl_nr                 name     e32      n32  gw_stockwerk  \
# messstelle_id
# 10000094           9  Richterich Nr. 11    292868  5632572           1.0
# 10000173          19  WALLENTHAL NR 20     328303  5604342           1.0
# 10132314          27  Zülpich 17 A         334240  5618380           1.0
# 10132326          28  Zülpich 17 B         334240  5618379           2.0
# 10133318          33  Euskirchen I/26      343605  5613273           1.0
#
#                grundstueck gemeinde_id gwhorizont_id  \
# messstelle_id
# 10000094       oeffentlich    05334002           NaN
# 10000173       oeffentlich    05366024            SM
# 10132314       oeffentlich    05366044            16
# 10132326       oeffentlich    05366044            9B
# 10133318       oeffentlich    05366016            16
#
#                                               gwhorizont gwleiter_id  \
# messstelle_id
# 10000094                                             NaN         kro
# 10000173                         Mittlerer Buntsandstein         NaN
# 10132314       Jüngere Hauptterrassen mit Lößauflagerung         NaN
# 10132326                                 Sande und Kiese         NaN
# 10133318       Jüngere Hauptterrassen mit Lößauflagerung         NaN
#
#                  gwleiter                 einrichtungsgrund gwk_lage_auf_id  \
# messstelle_id
# 10000094       Oberkreide  LGD                                   01.07.2016
# 10000173              NaN  keine Angabe                          01.07.2016
# 10132314              NaN  LGD                                   01.07.2016
# 10132326              NaN  LGD                                   01.07.2016
# 10133318              NaN  LGD                                   01.07.2016
#
#               gwk_lage_id gwk_monitoring_auf_id gwk_monitoring_id  \
# messstelle_id
# 10000094           282_09            01.07.2016            282_09
# 10000173           274_13            01.07.2016            274_13
# 10132314           274_07            01.07.2016            274_07
# 10132326           274_07            01.07.2016            274_07
# 10133318           274_09            01.07.2016            274_09
#
#               messprogramm  turnus_wasserstand freigabe_wstd freigabe_chemie  \
# messstelle_id
# 10000094               NaN  Messstelle inaktiv            ja            nein
# 10000173               NaN           monatlich            ja            nein
# 10132314               NaN           monatlich            ja            nein
# 10132326               NaN           monatlich            ja            nein
# 10133318               NaN  Messstelle inaktiv            ja            nein
#
#               freigabe_lage wasserstandsmessstelle guetemessstelle  \
# messstelle_id
# 10000094                 ja                     ja            nein
# 10000173                 ja                     ja            nein
# 10132314                 ja                     ja            nein
# 10132326                 ja                     ja            nein
# 10133318                 ja                     ja            nein
#
#               im_wrrl_messnetz_chemie im_wrrl_messnetz_wasserstand  \
# messstelle_id
# 10000094                         nein                         nein
# 10000173                         nein                           ja
# 10132314                         nein                         nein
# 10132326                         nein                         nein
# 10133318                         nein                         nein
#
#                                  messstellenart wasserart labor  \
# messstelle_id
# 10000094       Schachtbrunnen                         NaN   NaN
# 10000173       Schachtbrunnen                         NaN   NaN
# 10132314       GW-Messstelle                          NaN   NaN
# 10132326       GW-Messstelle                          NaN   NaN
# 10133318       GW-Messstelle                          NaN   NaN
#
#               beobachtung_wasserstand  \
# messstelle_id
# 10000094                            -
# 10000173                  durch LANUV
# 10132314                  durch LANUV
# 10132326                  durch LANUV
# 10133318                            -
#
#                                                      eigentuemer  \
# messstelle_id
# 10000094       Bahnbrunnen                                   ...
# 10000173       keine Angabe                                  ...
# 10132314       Land NRW                                      ...
# 10132326       Land NRW                                      ...
# 10133318       Land NRW                                      ...
#
#                                                        betreiber  \
# messstelle_id
# 10000094       keine Angabe                                  ...
# 10000173       keine Angabe                                  ...
# 10132314       Land NRW                                      ...
# 10132326       Land NRW                                      ...
# 10133318       Land NRW                                      ...
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 10000094                   NaN                 NaN                3000.0
# 10000173                   NaN                 NaN                1000.0
# 10132314                 100.0               200.0                 100.0
# 10132326                 200.0               200.0                 100.0
# 10133318                 100.0                 0.0                  80.0
#
#                historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 10000094                         NaN            954.0              17351.0
# 10000173                         NaN            400.0              37030.0
# 10132314                         NaN            530.0              17261.0
# 10132326                         NaN           3165.0              14721.0
# 10133318                         NaN            759.0              16816.0
#
#                unterkante_filter_cm
# messstelle_id
# 10000094                    17351.0
# 10000173                    37030.0
# 10132314                    17161.0
# 10132326                    14521.0
# 10133318                    16716.0

# %%
df_coord_problem=df.loc[[10000094, 10000045, 10000033, 47247101, 79921802],["e32","n32", "grundstueck"]]
df_coord_problem
# Out:
#                   e32      n32  grundstueck
# messstelle_id
# 10000094       292868  5632572  oeffentlich
# 10000045       299399  5650595       privat
# 10000033       3070xx  56583xx       privat
# 47247101           xx       xx
# 79921802          NaN      NaN

# %%
# Add column for precision
df["genau"] = 0

# (1) If the coord data is numeric then the precision is 1m
idx_coords_1m_prec = (df["e32"].str.isnumeric() == True)

# (3,4) Some stations don't have coordinates
# e32 and n32 strings are either NaN (Null) or "xx"
idx_coords_missing = (df["e32"].str.len() < 6) | (df["e32"].isnull() == True)

# (2) If coord data is avaliable but not numeric, then the numbers have been obscured with "XX" for the two least significant decimals.
idx_coords_100m_prec = ~idx_coords_missing &  ~(df["e32"].str.isnumeric() == True)

# %%
df[idx_coords_missing]
# Out:
#                sl_nr                 name  e32  n32  gw_stockwerk grundstueck  \
# messstelle_id
# 36446518       47111  WA-Lörick LR - RMM    xx   xx           NaN
# 36487600       46659  Wittlaer              xx   xx           NaN
# 47039000       46753  Mündelheim Rhein      xx   xx           NaN
# 47199003       47636  Sammelleitung 1-7     xx   xx           NaN
# 47200005       47638  Sammelleitung 10-20   xx   xx           NaN
# 47202002       47647  Sammelleitung 21-30   xx   xx           NaN
# 47247101       46769  RM-Moers Gerdt        xx   xx           NaN
# 47299009       47658  RM-Bucholtwelmen      xx   xx           NaN
# 59621035       46215  RM-Brunnen Stortel    xx   xx           NaN
# 68011003       47697  WW.HALTERNHAARD-MI    xx   xx           NaN
# 68012007       14582  WW.HALTERNWEST-MI     xx   xx           1.0
# 68013103       47705  WW.HALTERN-BRR A      xx   xx           NaN
# 68013206       47706  WW.HALTERN-BRR B      xx   xx           NaN
# 68013309       47707  WW.HALTERN-BRR G      xx   xx           NaN
# 68013401       47708  WW.HALTERN-BRR C/D    xx   xx           NaN
# 68013504       47709  WW.HALTERN-BRR E/F    xx   xx           NaN
# 68013607       47710  WW.HALTERN-BRR H/K    xx   xx           NaN
# 79921802       69491     Etzold_BN_868_SB  NaN  NaN           1.0
# 118010001      30831  WW.RIESENBECK-WAMI    xx   xx           1.0
# 118020006      30835  WW.IBBENB.LEHENWAMI   xx   xx           1.0
# 118260005      30882  WW.LETTE-WAMI         xx   xx           1.0
# 118550007      30917  WW.COESFELD-ORTWAMI   xx   xx           1.0
# 118620009      30928  WW.NEUENKIRCH.-WAMI   xx   xx           1.0
# 118650002      30946  WW.HOHE-WARD-WAMI     xx   xx           1.0
# 118810005      30979  WW.ORTHEIDE-WAMI      xx   xx           1.0
# 118820000      30991  WW.GREVEN.DAMM-WAMI   xx   xx           1.0
# 118840009      31022  WW.TELGTE-WAMI        xx   xx           1.0
# 118871900      31046  WW.WARENDORF-HEMI     xx   xx           1.0
# 118880007      31047  WW.VOHREN-DACK-WAMI   xx   xx           1.0
# 129700800      45778  RM-Zinse              xx   xx           NaN
#
#               gemeinde_id gwhorizont_id gwhorizont gwleiter_id gwleiter  \
# messstelle_id
# 36446518              NaN           NaN        NaN         NaN      NaN
# 36487600              NaN           NaN        NaN         NaN      NaN
# 47039000              NaN           NaN        NaN         NaN      NaN
# 47199003              NaN           NaN        NaN         NaN      NaN
# 47200005              NaN           NaN        NaN         NaN      NaN
# 47202002              NaN           NaN        NaN         NaN      NaN
# 47247101              NaN           NaN        NaN         NaN      NaN
# 47299009              NaN           NaN        NaN         NaN      NaN
# 59621035              NaN           NaN        NaN         NaN      NaN
# 68011003              NaN           NaN        NaN         NaN      NaN
# 68012007              NaN           NaN        NaN         NaN      NaN
# 68013103              NaN           NaN        NaN         NaN      NaN
# 68013206              NaN           NaN        NaN         NaN      NaN
# 68013309              NaN           NaN        NaN         NaN      NaN
# 68013401              NaN           NaN        NaN         NaN      NaN
# 68013504              NaN           NaN        NaN         NaN      NaN
# 68013607              NaN           NaN        NaN         NaN      NaN
# 79921802              NaN           NaN        NaN         NaN      NaN
# 118010001             NaN           NaN        NaN         NaN      NaN
# 118020006             NaN           NaN        NaN         NaN      NaN
# 118260005             NaN           NaN        NaN         NaN      NaN
# 118550007             NaN           NaN        NaN         NaN      NaN
# 118620009             NaN           NaN        NaN         NaN      NaN
# 118650002             NaN           NaN        NaN         NaN      NaN
# 118810005             NaN           NaN        NaN         NaN      NaN
# 118820000             NaN           NaN        NaN         NaN      NaN
# 118840009             NaN           NaN        NaN         NaN      NaN
# 118871900             NaN           NaN        NaN         NaN      NaN
# 118880007             NaN           NaN        NaN         NaN      NaN
# 129700800             NaN           NaN        NaN         NaN      NaN
#
#                               einrichtungsgrund gwk_lage_auf_id gwk_lage_id  \
# messstelle_id
# 36446518       Eigenüberwachung Wasserwerk                  NaN         NaN
# 36487600       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47039000       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47199003       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47200005       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47202002       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47247101       Eigenüberwachung Wasserwerk                  NaN         NaN
# 47299009       Eigenüberwachung Wasserwerk                  NaN         NaN
# 59621035       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68011003       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68012007       keine Angabe                                 NaN         NaN
# 68013103       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013206       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013309       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013401       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013504       Eigenüberwachung Wasserwerk                  NaN         NaN
# 68013607       Eigenüberwachung Wasserwerk                  NaN         NaN
# 79921802       keine Angabe                                 NaN         NaN
# 118010001      keine Angabe                          01.07.2016        3_15
# 118020006      keine Angabe                          01.07.2016        3_15
# 118260005      keine Angabe                          01.07.2016      278_11
# 118550007      keine Angabe                          01.07.2016      928_19
# 118620009      keine Angabe                          01.07.2016    928_07_1
# 118650002      keine Angabe                          01.07.2016        3_10
# 118810005      keine Angabe                          01.07.2016        3_04
# 118820000      keine Angabe                          01.07.2016        3_04
# 118840009      keine Angabe                          01.07.2016        3_06
# 118871900      keine Angabe                          01.07.2016        3_07
# 118880007      keine Angabe                          01.07.2016        3_07
# 129700800      Eigenüberwachung Wasserwerk                  NaN         NaN
#
#               gwk_monitoring_auf_id gwk_monitoring_id  \
# messstelle_id
# 36446518                        NaN               NaN
# 36487600                        NaN               NaN
# 47039000                        NaN               NaN
# 47199003                        NaN               NaN
# 47200005                        NaN               NaN
# 47202002                        NaN               NaN
# 47247101                        NaN               NaN
# 47299009                        NaN               NaN
# 59621035                        NaN               NaN
# 68011003                        NaN               NaN
# 68012007                        NaN               NaN
# 68013103                        NaN               NaN
# 68013206                        NaN               NaN
# 68013309                        NaN               NaN
# 68013401                        NaN               NaN
# 68013504                        NaN               NaN
# 68013607                        NaN               NaN
# 79921802                        NaN               NaN
# 118010001                01.07.2016              3_15
# 118020006                01.07.2016              3_15
# 118260005                01.07.2016            278_11
# 118550007                01.07.2016            928_19
# 118620009                01.07.2016          928_07_1
# 118650002                01.07.2016              3_10
# 118810005                01.07.2016              3_04
# 118820000                01.07.2016              3_04
# 118840009                01.07.2016              3_06
# 118871900                01.07.2016              3_07
# 118880007                01.07.2016              3_07
# 129700800                       NaN               NaN
#
#                               messprogramm             turnus_wasserstand  \
# messstelle_id
# 36446518       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 36487600       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 47039000       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 47199003       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 47200005       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 47202002       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 47247101       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 47299009       RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 59621035       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68011003       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68012007       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68013103       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68013206       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68013309       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68013401       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68013504       RWÜ (keine GWÜ-Messstellen)                            NaN
# 68013607       RWÜ (keine GWÜ-Messstellen)                            NaN
# 79921802                               NaN                  Einzelmessung
# 118010001      RWÜ (keine GWÜ-Messstellen)  Messstelle besteht nicht mehr
# 118020006      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118260005      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118550007      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118620009      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118650002      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118810005      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118820000      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118840009      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118871900      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 118880007      RWÜ (keine GWÜ-Messstellen)             Messstelle inaktiv
# 129700800      RWÜ (keine GWÜ-Messstellen)                            NaN
#
#               freigabe_wstd freigabe_chemie freigabe_lage  \
# messstelle_id
# 36446518               nein            nein          nein
# 36487600               nein            nein          nein
# 47039000               nein            nein          nein
# 47199003               nein            nein          nein
# 47200005               nein            nein          nein
# 47202002               nein            nein          nein
# 47247101               nein            nein          nein
# 47299009               nein            nein          nein
# 59621035               nein            nein          nein
# 68011003               nein            nein          nein
# 68012007               nein            nein          nein
# 68013103               nein            nein          nein
# 68013206               nein            nein          nein
# 68013309               nein            nein          nein
# 68013401               nein            nein          nein
# 68013504               nein            nein          nein
# 68013607               nein            nein          nein
# 79921802               nein            nein            ja
# 118010001              nein            nein          nein
# 118020006              nein            nein          nein
# 118260005              nein            nein          nein
# 118550007              nein            nein          nein
# 118620009              nein            nein          nein
# 118650002              nein            nein          nein
# 118810005              nein            nein          nein
# 118820000              nein            nein          nein
# 118840009              nein            nein          nein
# 118871900              nein            nein          nein
# 118880007              nein            nein          nein
# 129700800              nein            nein          nein
#
#               wasserstandsmessstelle guetemessstelle im_wrrl_messnetz_chemie  \
# messstelle_id
# 36446518                          ja              ja                    nein
# 36487600                          ja              ja                    nein
# 47039000                          ja              ja                    nein
# 47199003                          ja              ja                    nein
# 47200005                          ja              ja                    nein
# 47202002                          ja              ja                    nein
# 47247101                          ja              ja                    nein
# 47299009                          ja              ja                    nein
# 59621035                        nein              ja                    nein
# 68011003                        nein              ja                    nein
# 68012007                        nein              ja                    nein
# 68013103                        nein              ja                    nein
# 68013206                        nein              ja                    nein
# 68013309                        nein              ja                    nein
# 68013401                        nein              ja                    nein
# 68013504                        nein              ja                    nein
# 68013607                        nein              ja                    nein
# 79921802                          ja            nein                    nein
# 118010001                         ja              ja                    nein
# 118020006                         ja              ja                    nein
# 118260005                         ja              ja                    nein
# 118550007                         ja              ja                    nein
# 118620009                         ja              ja                    nein
# 118650002                         ja              ja                    nein
# 118810005                         ja              ja                    nein
# 118820000                         ja              ja                    nein
# 118840009                         ja              ja                    nein
# 118871900                         ja              ja                    nein
# 118880007                         ja              ja                    nein
# 129700800                       nein              ja                    nein
#
#               im_wrrl_messnetz_wasserstand                    messstellenart  \
# messstelle_id
# 36446518                              nein  Sammelmessstelle
# 36487600                              nein  Sammelmessstelle
# 47039000                              nein   Talsperre, Flusswassermesstelle
# 47199003                              nein  Sammelmessstelle
# 47200005                              nein  Sammelmessstelle
# 47202002                              nein  Sammelmessstelle
# 47247101                              nein  Rohmischwassermessstelle
# 47299009                              nein  Rohmischwassermessstelle
# 59621035                              nein  Rohmischwassermessstelle
# 68011003                              nein  Sammelmessstelle
# 68012007                              nein  Sammelmessstelle
# 68013103                              nein  Sammelmessstelle
# 68013206                              nein  Sammelmessstelle
# 68013309                              nein  Sammelmessstelle
# 68013401                              nein  Sammelmessstelle
# 68013504                              nein  Sammelmessstelle
# 68013607                              nein  Sammelmessstelle
# 79921802                              nein             Vertikalfilterbrunnen
# 118010001                             nein  Rohmischwassermessstelle
# 118020006                             nein  Rohmischwassermessstelle
# 118260005                             nein  Rohmischwassermessstelle
# 118550007                             nein  Rohmischwassermessstelle
# 118620009                             nein  Rohmischwassermessstelle
# 118650002                             nein  Rohmischwassermessstelle
# 118810005                             nein  Rohmischwassermessstelle
# 118820000                             nein  Rohmischwassermessstelle
# 118840009                             nein  Rohmischwassermessstelle
# 118871900                             nein  Rohmischwassermessstelle
# 118880007                             nein  Rohmischwassermessstelle
# 129700800                             nein  Rohmischwassermessstelle
#
#                   wasserart labor beobachtung_wasserstand  \
# messstelle_id
# 36446518       keine Angabe     -                       -
# 36487600       keine Angabe     -                       -
# 47039000       keine Angabe     -                       -
# 47199003       keine Angabe     -                       -
# 47200005       keine Angabe     -                       -
# 47202002       keine Angabe     -                       -
# 47247101       keine Angabe     -                       -
# 47299009       keine Angabe     -                       -
# 59621035       keine Angabe     -                     NaN
# 68011003       keine Angabe     -                     NaN
# 68012007       keine Angabe     -                     NaN
# 68013103       keine Angabe     -                     NaN
# 68013206       keine Angabe     -                     NaN
# 68013309       keine Angabe     -                     NaN
# 68013401       keine Angabe     -                     NaN
# 68013504       keine Angabe     -                     NaN
# 68013607       keine Angabe     -                     NaN
# 79921802                NaN   NaN                       -
# 118010001      keine Angabe     -                       -
# 118020006      keine Angabe     -                       -
# 118260005      keine Angabe     -                       -
# 118550007      keine Angabe     -                       -
# 118620009      keine Angabe     -                       -
# 118650002      keine Angabe     -                       -
# 118810005      keine Angabe     -                       -
# 118820000      keine Angabe     -                       -
# 118840009      keine Angabe     -                       -
# 118871900      keine Angabe     -                       -
# 118880007      keine Angabe     -                       -
# 129700800      keine Angabe     -                     NaN
#
#                                                      eigentuemer  \
# messstelle_id
# 36446518                                                     NaN
# 36487600                                                     NaN
# 47039000                                                     NaN
# 47199003                                                     NaN
# 47200005                                                     NaN
# 47202002                                                     NaN
# 47247101                                                     NaN
# 47299009                                                     NaN
# 59621035                                                     NaN
# 68011003                                                     NaN
# 68012007                                                     NaN
# 68013103                                                     NaN
# 68013206                                                     NaN
# 68013309                                                     NaN
# 68013401                                                     NaN
# 68013504                                                     NaN
# 68013607                                                     NaN
# 79921802                                                     NaN
# 118010001                                                    NaN
# 118020006                                                    NaN
# 118260005                                                    NaN
# 118550007                                                    NaN
# 118620009                                                    NaN
# 118650002                                                    NaN
# 118810005                                                    NaN
# 118820000                                                    NaN
# 118840009                                                    NaN
# 118871900                                                    NaN
# 118880007                                                    NaN
# 129700800      Wasserverband Siegen-Wittgenstein             ...
#
#                                                        betreiber  \
# messstelle_id
# 36446518                                                     NaN
# 36487600                                                     NaN
# 47039000                                                     NaN
# 47199003                                                     NaN
# 47200005                                                     NaN
# 47202002                                                     NaN
# 47247101                                                     NaN
# 47299009                                                     NaN
# 59621035                                                     NaN
# 68011003                                                     NaN
# 68012007                                                     NaN
# 68013103                                                     NaN
# 68013206                                                     NaN
# 68013309                                                     NaN
# 68013401                                                     NaN
# 68013504                                                     NaN
# 68013607                                                     NaN
# 79921802                                                     NaN
# 118010001                                                    NaN
# 118020006                                                    NaN
# 118260005                                                    NaN
# 118550007                                                    NaN
# 118620009                                                    NaN
# 118650002                                                    NaN
# 118810005                                                    NaN
# 118820000                                                    NaN
# 118840009                                                    NaN
# 118871900                                                    NaN
# 118880007                                                    NaN
# 129700800      Wasserverband Siegen-Wittgenstein             ...
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 36446518                   NaN                 NaN                   NaN
# 36487600                   NaN                 NaN                   NaN
# 47039000                   NaN                 NaN                   NaN
# 47199003                   NaN                 NaN                   NaN
# 47200005                   NaN                 NaN                   NaN
# 47202002                   NaN                 NaN                   NaN
# 47247101                   NaN                 NaN                   NaN
# 47299009                   NaN                 NaN                   NaN
# 59621035                   NaN                 NaN                   NaN
# 68011003                   NaN                 NaN                   NaN
# 68012007                   NaN                 NaN                   NaN
# 68013103                   NaN                 NaN                   NaN
# 68013206                   NaN                 NaN                   NaN
# 68013309                   NaN                 NaN                   NaN
# 68013401                   NaN                 NaN                   NaN
# 68013504                   NaN                 NaN                   NaN
# 68013607                   NaN                 NaN                   NaN
# 79921802                   NaN                 NaN                   NaN
# 118010001                  NaN                 NaN                   NaN
# 118020006                  NaN                 NaN                   NaN
# 118260005                  NaN                 NaN                   NaN
# 118550007                  NaN                 NaN                   NaN
# 118620009                  NaN                 NaN                   NaN
# 118650002                  NaN                 0.0                   NaN
# 118810005                  NaN                 NaN                   NaN
# 118820000                  NaN                 NaN                   NaN
# 118840009                  NaN                 NaN                   NaN
# 118871900                  NaN                 NaN                 300.0
# 118880007                  NaN                 NaN                   NaN
# 129700800                  NaN                 NaN                   NaN
#
#                historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 36446518                         NaN              NaN                  NaN
# 36487600                         NaN              NaN                  NaN
# 47039000                         NaN              NaN                  NaN
# 47199003                         NaN              NaN                  NaN
# 47200005                         NaN              NaN                  NaN
# 47202002                         NaN              NaN                  NaN
# 47247101                         NaN              NaN                  NaN
# 47299009                         NaN              NaN                  NaN
# 59621035                         NaN              NaN                  NaN
# 68011003                         NaN              NaN                  NaN
# 68012007                         NaN              NaN                  NaN
# 68013103                         NaN              NaN                  NaN
# 68013206                         NaN              NaN                  NaN
# 68013309                         NaN              NaN                  NaN
# 68013401                         NaN              NaN                  NaN
# 68013504                         NaN              NaN                  NaN
# 68013607                         NaN              NaN                  NaN
# 79921802                         NaN           1450.0               3650.0
# 118010001                        NaN          13110.0              -1111.0
# 118020006                        NaN           8829.0                170.0
# 118260005                        NaN           9065.0              -1974.0
# 118550007                        NaN          12450.0              -3710.0
# 118620009                        NaN           2095.0               3164.0
# 118650002                        NaN            620.0               5400.0
# 118810005                        NaN           2210.0               1789.0
# 118820000                        NaN           2594.0               1945.0
# 118840009                        NaN           2179.0               2859.0
# 118871900                        NaN           1267.0               4166.0
# 118880007                        NaN            786.0               4713.0
# 129700800                        NaN              NaN                  NaN
#
#                unterkante_filter_cm  genau
# messstelle_id
# 36446518                        NaN      0
# 36487600                        NaN      0
# 47039000                        NaN      0
# 47199003                        NaN      0
# 47200005                        NaN      0
# 47202002                        NaN      0
# 47247101                        NaN      0
# 47299009                        NaN      0
# 59621035                        NaN      0
# 68011003                        NaN      0
# 68012007                        NaN      0
# 68013103                        NaN      0
# 68013206                        NaN      0
# 68013309                        NaN      0
# 68013401                        NaN      0
# 68013504                        NaN      0
# 68013607                        NaN      0
# 79921802                     3650.0      0
# 118010001                   -1111.0      0
# 118020006                     170.0      0
# 118260005                   -1974.0      0
# 118550007                   -3710.0      0
# 118620009                    3164.0      0
# 118650002                    5400.0      0
# 118810005                    1789.0      0
# 118820000                    1945.0      0
# 118840009                    2859.0      0
# 118871900                    4166.0      0
# 118880007                    4713.0      0
# 129700800                       NaN      0

# %%
df.loc[idx_coords_1m_prec,"e32num"] = df.loc[idx_coords_1m_prec,"e32"].astype(float)
df.loc[idx_coords_1m_prec,"n32num"] = df.loc[idx_coords_1m_prec,"n32"].astype(float)
df.loc[idx_coords_1m_prec, "genau"] = 1

# %%
df.loc[idx_coords_100m_prec,"e32num"] = (df.loc[idx_coords_100m_prec,"e32"].str[:-2]+"50").astype(float)
df.loc[idx_coords_100m_prec,"n32num"] = (df.loc[idx_coords_100m_prec,"n32"].str[:-2]+"50").astype(float)
df.loc[idx_coords_100m_prec, "genau"] = 100

# %%
df.loc[idx_coords_missing,"e32num"] = -999.9
df.loc[idx_coords_missing,"n32num"] = -999.9
df.loc[idx_coords_missing, "genau"] = -999

# %%
# check if all records have been matched
num_of_1m_prec = df[df["genau"] == 1].shape[0]
num_of_100m_prec = df[df["genau"] == 100].shape[0]
num_of_no_prec = df[df["genau"] == -999].shape[0]

num_check = num_of_1m_prec + num_of_100m_prec + num_of_no_prec

print(f"total num of recs:                        {num_total:6d}")
print(f"number of recs with 1m coord precision:   {num_of_1m_prec:6d}")
print(f"number of recs with 100m coord precision: {num_of_100m_prec:6d}")
print(f"number of recs with no coords:            {num_of_no_prec:6d}")
print(f"check sum:                                {num_check:6d}")

assert num_check == num_total, "ERROR. Mismatch in numbers of stations"
# Out:
# total num of recs:                         71120
# number of recs with 1m coord precision:    59280
# number of recs with 100m coord precision:  11810
# number of recs with no coords:                30
# check sum:                                 71120

# %%
df[["e32","e32num","n32","n32num","genau"]].to_csv("check.csv")
df[["e32","e32num","n32","n32num","genau"]]
# Out:
#                   e32    e32num      n32     n32num  genau
# messstelle_id
# 10000008       3068xx  306850.0  56254xx  5625450.0    100
# 10000010       2935xx  293550.0  56452xx  5645250.0    100
# 10000021       312776  312776.0  5660432  5660432.0      1
# 10000033       3070xx  307050.0  56583xx  5658350.0    100
# 10000045       299399  299399.0  5650595  5650595.0      1
# ...               ...       ...      ...        ...    ...
# 289382210      345323  345323.0  5659935  5659935.0      1
# 289382221      345323  345323.0  5659935  5659935.0      1
# 289382518      345603  345603.0  5659991  5659991.0      1
# 289382520      345603  345603.0  5659991  5659991.0      1
# 289382713      344170  344170.0  5660121  5660121.0      1
#
# [71120 rows x 5 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
df2 = df[df["genau"] > 0]

# %%
df2.shape
# Out:
# (71090, 41)

# %%
# %%time
gdf = gpd.GeoDataFrame(df2, geometry=gpd.points_from_xy(df2.e32num, df2.n32num), crs="EPSG:25832")
# Out:
# CPU times: total: 46.9 ms
# Wall time: 67.9 ms

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 71090 entries, 10000008 to 289382713
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   sl_nr                         71090 non-null  int64
#  1   name                          71090 non-null  object
#  2   e32                           71090 non-null  object
#  3   n32                           71090 non-null  object
#  4   gw_stockwerk                  54173 non-null  float64
#  5   grundstueck                   71090 non-null  object
#  6   gemeinde_id                   71090 non-null  object
#  7   gwhorizont_id                 28424 non-null  object
#  8   gwhorizont                    28424 non-null  object
#  9   gwleiter_id                   2690 non-null   object
#  10  gwleiter                      2690 non-null   object
#  11  einrichtungsgrund             71090 non-null  object
#  12  gwk_lage_auf_id               70475 non-null  object
#  13  gwk_lage_id                   70475 non-null  object
#  14  gwk_monitoring_auf_id         70724 non-null  object
#  15  gwk_monitoring_id             70724 non-null  object
#  16  messprogramm                  16878 non-null  object
#  17  turnus_wasserstand            67690 non-null  object
#  18  freigabe_wstd                 71090 non-null  object
#  19  freigabe_chemie               71090 non-null  object
#  20  freigabe_lage                 71090 non-null  object
#  21  wasserstandsmessstelle        71090 non-null  object
#  22  guetemessstelle               71090 non-null  object
#  23  im_wrrl_messnetz_chemie       71090 non-null  object
#  24  im_wrrl_messnetz_wasserstand  71090 non-null  object
#  25  messstellenart                71090 non-null  object
#  26  wasserart                     16878 non-null  object
#  27  labor                         16878 non-null  object
#  28  beobachtung_wasserstand       68145 non-null  object
#  29  eigentuemer                   45634 non-null  object
#  30  betreiber                     45128 non-null  object
#  31  filterlaenge_cm               38356 non-null  float64
#  32  sumpfrohrlaenge_cm            32200 non-null  float64
#  33  ausbaudurchmesser_mm          43277 non-null  float64
#  34  historischer_ruhe_wsp         792 non-null    float64
#  35  einbaulaenge_cm               59275 non-null  float64
#  36  oberkante_filter_cm           59275 non-null  float64
#  37  unterkante_filter_cm          59275 non-null  float64
#  38  genau                         71090 non-null  int64
#  39  e32num                        71090 non-null  float64
#  40  n32num                        71090 non-null  float64
#  41  geometry                      71090 non-null  geometry
# dtypes: float64(10), geometry(1), int64(2), object(29)
# memory usage: 23.3+ MB

# %%
gdf.head(3)
# Out:
#                sl_nr                         name     e32      n32  \
# messstelle_id
# 10000008       70796  P3-BSR/Mariaschacht P 5 neu  3068xx  56254xx
# 10000010           1          SCHERPENSEEL NR 1    2935xx  56452xx
# 10000021           2          Bellinghoven Nr. 2   312776  5660432
#
#                gw_stockwerk grundstueck gemeinde_id gwhorizont_id  \
# messstelle_id
# 10000008                1.0                05334032           NaN
# 10000010                1.0      privat    05370028            6D
# 10000021                1.0      privat    05370004            14
#
#                           gwhorizont gwleiter_id gwleiter  \
# messstelle_id
# 10000008                         NaN         NaN      NaN
# 10000010              Neurather Sand         NaN      NaN
# 10000021       Ältere Hauptterrassen         NaN      NaN
#
#                               einrichtungsgrund gwk_lage_auf_id gwk_lage_id  \
# messstelle_id
# 10000008       GW-Beschaffenheit                     01.07.2016      282_11
# 10000010       LGD                                   01.07.2016       28_04
# 10000021       LGD                                   01.07.2016      286_07
#
#               gwk_monitoring_auf_id gwk_monitoring_id  \
# messstelle_id
# 10000008                 01.07.2016            282_11
# 10000010                 01.07.2016             28_04
# 10000021                 01.07.2016            286_07
#
#                                    messprogramm  \
# messstelle_id
# 10000008       RWÜ (Messstelle f. GWÜ geeignet)
# 10000010             Grundwassergüteüberwachung
# 10000021                                    NaN
#
#                           turnus_wasserstand freigabe_wstd freigabe_chemie  \
# messstelle_id
# 10000008                           monatlich          nein            nein
# 10000010       Messstelle besteht nicht mehr            ja              ja
# 10000021                  Messstelle inaktiv            ja            nein
#
#               freigabe_lage wasserstandsmessstelle guetemessstelle  \
# messstelle_id
# 10000008               nein                     ja              ja
# 10000010               nein                     ja              ja
# 10000021                 ja                     ja            nein
#
#               im_wrrl_messnetz_chemie im_wrrl_messnetz_wasserstand  \
# messstelle_id
# 10000008                         nein                         nein
# 10000010                         nein                         nein
# 10000021                         nein                         nein
#
#                                  messstellenart     wasserart labor  \
# messstelle_id
# 10000008       GW-Messstelle                     keine Angabe     -
# 10000010       GW-Messstelle                     keine Angabe     -
# 10000021       Schachtbrunnen                             NaN   NaN
#
#               beobachtung_wasserstand  \
# messstelle_id
# 10000008                            -
# 10000010                            -
# 10000021                            -
#
#                                                      eigentuemer  \
# messstelle_id
# 10000008       BSR Schotterwerk                              ...
# 10000010       Land NRW                                      ...
# 10000021       keine Angabe                                  ...
#
#                                                        betreiber  \
# messstelle_id
# 10000008       Enwor GmbH                                    ...
# 10000010       keine Angabe                                  ...
# 10000021       keine Angabe                                  ...
#
#                filterlaenge_cm  sumpfrohrlaenge_cm  ausbaudurchmesser_mm  \
# messstelle_id
# 10000008                 700.0                 NaN                  80.0
# 10000010                 400.0                 NaN                 100.0
# 10000021                   NaN                 NaN                1000.0
#
#                historischer_ruhe_wsp  einbaulaenge_cm  oberkante_filter_cm  \
# messstelle_id
# 10000008                         NaN           1570.0              21053.0
# 10000010                         NaN           4936.0               7731.0
# 10000021                         NaN           1411.0               7885.0
#
#                unterkante_filter_cm  genau    e32num     n32num  \
# messstelle_id
# 10000008                    20353.0    100  306850.0  5625450.0
# 10000010                     7331.0    100  293550.0  5645250.0
# 10000021                     7885.0      1  312776.0  5660432.0
#
#                                      geometry
# messstelle_id
# 10000008       POINT (306850.000 5625450.000)
# 10000010       POINT (293550.000 5645250.000)
# 10000021       POINT (312776.000 5660432.000)

# %%
# %%time

# This takes 90 secs on my computer!

gdf.to_file("GW_Stations.gpkg", layer='GW Stations', driver="GPKG")
# Out:
# CPU times: total: 22.4 s
# Wall time: 28.2 s

# %%
# %load_ext sql

# %%
print("Connect")
# %sql postgresql://env_master:M123xyz@localhost/env_db
# Out:
# Connect

# %%
# %%sql
# SELECT * FROM information_schema.schemata
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 4 rows affected.
# [('env_db', 'public', 'pg_database_owner', None, None, None, None),
#  ('env_db', 'information_schema', 'postgres', None, None, None, None),
#  ('env_db', 'pg_catalog', 'postgres', None, None, None, None),
#  ('env_db', 'pg_toast', 'postgres', None, None, None, None)]

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS gw AUTHORIZATION env_master
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# SELECT * FROM information_schema.schemata;
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 5 rows affected.
# [('env_db', 'public', 'pg_database_owner', None, None, None, None),
#  ('env_db', 'information_schema', 'postgres', None, None, None, None),
#  ('env_db', 'pg_catalog', 'postgres', None, None, None, None),
#  ('env_db', 'pg_toast', 'postgres', None, None, None, None),
#  ('env_db', 'gw', 'env_master', None, None, None, None)]

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("postgresql://env_master:M123xyz@localhost/env_db")
# fast_executemany=True
# use_batch_mode=True

# %%
# %%time
gdf.to_postgis(con=engine, name="gw_stations", schema="gw", index=True, chunksize=100, if_exists="replace")
# Out:
# CPU times: total: 844 ms
# Wall time: 2.53 s

# %%
# %%sql
# alter table gw.gw_stations add constraint pk_gw_stations primary key (messstelle_id)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %% [markdown]
# # Groundwater "Quality Data": Chemistry!

# %% [markdown]
# ## Data Directories and Files

# %%
gw_quality_fname = r"opendata.gw_chemischer_messwert.csv"
gw_quality_pfname = data_in_dir + gw_quality_fname
print(f"Qualitätsdaten: {gw_quality_pfname:s}")
# Out:
# Qualitätsdaten: ../GeoInfo_WS2023_2_Final_D/data/original/opendata.gw_chemischer_messwert.csv

# %%
fh = open(gw_quality_pfname,"r", encoding = "utf-8", newline = '')
s = fh.readline()
s = s.replace('"', '').strip()
header_de = s[1:].split(';')
header_de
# Out:
# ['sl_nr',
#  'messstelle_id',
#  'pna_id',
#  'datum_pn',
#  'stoff_nr',
#  'probengut',
#  'messergebnis_c',
#  'messergebnis_hinweis',
#  'bestimmungsgrenze',
#  'masseinheit',
#  'trennverfahren',
#  'verfahren',
#  'vor_ort',
#  'herkunft',
#  'aktual_dat',
#  'erstell_dat']

# %%
# %time df_qual = pd.read_csv(gw_quality_pfname, sep = ";", dtype = {"messergebnis_c":str ,"messergebnis_hinweis":str }, nrows = 5)
# Out:
# CPU times: total: 0 ns
# Wall time: 11 ms

# %%
df_qual.head(5)
# Out:
#      sl_nr  messstelle_id       pna_id  datum_pn  stoff_nr    probengut  \
# 0  2903561       59620687  5/2005/4599  20051018      1164  Grundwasser
# 1  2903564       59620687  5/2005/4599  20051018      1061  Grundwasser
# 2  2903565       59620687  5/2005/4599  20051018      1011  Grundwasser
# 3  2903584       59620389  5/2005/5002  20051114      1011  Grundwasser
# 4  2903585       59620080  5/2005/5001  20051111      1061  Grundwasser
#
#   messergebnis_c messergebnis_hinweis  bestimmungsgrenze masseinheit  \
# 0       22.00000                  NaN                NaN        µg/l
# 1        6.80000                  NaN                NaN           -
# 2       12.80000                  NaN                NaN          °C
# 3       12.30000                  NaN                NaN          °C
# 4        7.40000                  NaN                NaN           -
#
#   trennverfahren                   verfahren vor_ort    herkunft  aktual_dat  \
# 0   Gesamtgehalt    DIN 38406-E22 MAERZ 1988          HYGC_BR-AR    20051205
# 1   Gesamtgehalt    DIN 38404-C5 JANUAR 1984      ja  HYGC_BR-AR    20051205
# 2   Gesamtgehalt  DIN 38404-C4 DEZEMBER 1976      ja  HYGC_BR-AR    20051205
# 3   Gesamtgehalt  DIN 38404-C4 DEZEMBER 1976      ja  HYGC_BR-AR    20051205
# 4   Gesamtgehalt    DIN 38404-C5 JANUAR 1984      ja  HYGC_BR-AR    20051205
#
#    erstell_dat
# 0     20051205
# 1     20051205
# 2     20051205
# 3     20051205
# 4     20051205

# %%
df_qual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sl_nr                 5 non-null      int64
#  1   messstelle_id         5 non-null      int64
#  2   pna_id                5 non-null      object
#  3   datum_pn              5 non-null      int64
#  4   stoff_nr              5 non-null      int64
#  5   probengut             5 non-null      object
#  6   messergebnis_c        5 non-null      object
#  7   messergebnis_hinweis  0 non-null      object
#  8   bestimmungsgrenze     0 non-null      float64
#  9   masseinheit           5 non-null      object
#  10  trennverfahren        5 non-null      object
#  11  verfahren             5 non-null      object
#  12  vor_ort               5 non-null      object
#  13  herkunft              5 non-null      object
#  14  aktual_dat            5 non-null      int64
#  15  erstell_dat           5 non-null      int64
# dtypes: float64(1), int64(6), object(9)
# memory usage: 772.0+ bytes

# %% [markdown]
# **The complete CSV file with the measured values of the chemical analyses comprises more than 3.6 million measured values!**

# %%
# Wall time: 13 s
# %time df_qual = pd.read_csv(gw_quality_pfname, sep = ";", index_col=["sl_nr"], \
                            dtype = {"messergebnis_c":str ,"messergebnis_hinweis":str }, \
                            parse_dates = ["datum_pn", "aktual_dat", "erstell_dat"])
# Out:
# CPU times: total: 31.6 s
# Wall time: 34.9 s

# %%
df_qual.shape
# Out:
# (3671913, 15)

# %%
df_qual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3671913 entries, 2903561 to 2882795
# Data columns (total 15 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   messstelle_id         int64
#  1   pna_id                object
#  2   datum_pn              datetime64[ns]
#  3   stoff_nr              int64
#  4   probengut             object
#  5   messergebnis_c        object
#  6   messergebnis_hinweis  object
#  7   bestimmungsgrenze     float64
#  8   masseinheit           object
#  9   trennverfahren        object
#  10  verfahren             object
#  11  vor_ort               object
#  12  herkunft              object
#  13  aktual_dat            datetime64[ns]
#  14  erstell_dat           datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(2), object(9)
# memory usage: 448.2+ MB

# %%
# duplicate sl_nr values? Can it be a unique index?
# Result should be empty
print(df_qual[df_qual.index.duplicated()])
# Out:
# Empty DataFrame
# Columns: [messstelle_id, pna_id, datum_pn, stoff_nr, probengut, messergebnis_c, messergebnis_hinweis, bestimmungsgrenze, masseinheit, trennverfahren, verfahren, vor_ort, herkunft, aktual_dat, erstell_dat]
# Index: []

# %%
# time series example
# stoff_nr=1244 ->"Nitrat"
idx = (df_qual["messstelle_id"] == 20002129) & (df_qual["stoff_nr"] == 1244)
df_qual.loc[idx,["datum_pn", "messergebnis_c"]].sort_values("datum_pn")
# Out:
#            datum_pn messergebnis_c
# sl_nr
# 12222093 1985-09-04       20.36420
# 12149275 1986-05-05       22.57770
# 12222368 1986-12-11       42.94190
# 12222587 1987-05-22       23.02040
# 12222658 1987-11-17       37.18680
# 12149846 1988-07-08       44.27000
# 12149887 1988-10-27       66.40500
# 12222967 1989-11-28       75.25900
# 12223110 1990-07-06      101.82100
# 12223236 1991-09-18       97.39400
# 12223443 1992-12-02      133.25270
# 12223877 1994-01-25      146.09100
# 12223990 1994-08-22      163.79900
# 12151301 1995-11-28      123.95600
# 12226453 1996-12-16      115.10200
# 12229266 1997-12-09      117.31550
# 12231300 1998-05-04      110.67500
# 12231744 1999-05-26      104.03450
# 12232457 1999-09-21      112.44580
# 12234590 2000-11-29      128.38300
# 12236030 2001-04-06      119.52900
# 12237559 2001-10-23      112.44580
# 12238342 2002-09-18      110.23230
# 12238332 2002-10-31      108.01880
# 12238861 2003-04-24      101.82100
# 12366699 2003-10-15       77.02980
# 12241338 2004-04-08       92.96700
# 12241353 2004-06-01       84.11300
# 12242452 2005-08-11       84.11300
# 12242524 2005-08-31       84.11300
# 12279251 2006-05-24       75.25900
# 12172832 2007-06-29       79.68600
# 12172840 2008-04-25       66.40500
# 12357765 2009-06-16       79.68600
# 12365025 2010-04-14      106.24800
# 12373604 2011-06-15       92.96700
# 12384379 2012-11-29       79.68600
# 12404546 2015-07-22       60.20720
# 12410216 2016-05-18       61.97800
# 12423378 2017-09-13      101.82100
# 16131017 2019-08-01      101.82000

# %% [markdown]
# ### Tests for different measurement value string cases
#
# ```
# (1)   "1.00" (is_float)
# (2)  "<1.00" (is_less)
# (3)  ">1.00" (is_greater)
# ```

# %%
# check if string can be converted to float
def is_float(element: str) -> bool:
    try:
        float(element)
        return True
    except ValueError:
        return False

# %%
# check if string starts with '<'
def is_less(element: str) -> bool:
    return element[0] == "<"

# %%
# check if string starts with '>'
def is_greater(element: str) -> bool:
    return element[0] == ">"

# %%
print("is_float()")
print(is_float("<1.234"))
print(is_float(">1.234"))
print(is_float("-1.234"))
# Out:
# is_float()
# False
# False
# True

# %%
# Some test applications
print("is_less()")
print(is_less("<1.234"))
print(is_less(">1.234"))
print(is_less("1.234"))
print("is_greater()")
print(is_greater("<1.234"))
print(is_greater(">1.234"))
print(is_greater("1.234"))
print("is_float()")
print(is_float("<1.234"))
print(is_float(">1.234"))
print(is_float("1.234"))
# Out:
# is_less()
# True
# False
# False
# is_greater()
# False
# True
# False
# is_float()
# False
# False
# True

# %%
# Apply the tests and create Boolean indexes
# %time idx_mess_is_float   = df_qual["messergebnis_c"].apply(is_float)
# %time idx_mess_is_less    = df_qual["messergebnis_c"].apply(is_less)
# %time idx_mess_is_greater = df_qual["messergebnis_c"].apply(is_greater)
# Out:
# CPU times: total: 2.48 s
# Wall time: 2.92 s
# CPU times: total: 547 ms
# Wall time: 588 ms
# CPU times: total: 469 ms
# Wall time: 591 ms

# %%
# Print records which are neither less nor greater nor float -> should be empty data frame
assert df_qual[~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float].shape[0] == 0

# Dataframe should be empty
print(df_qual[~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float])
# Out:
# Empty DataFrame
# Columns: [messstelle_id, pna_id, datum_pn, stoff_nr, probengut, messergebnis_c, messergebnis_hinweis, bestimmungsgrenze, masseinheit, trennverfahren, verfahren, vor_ort, herkunft, aktual_dat, erstell_dat]
# Index: []

# %%
# res = (~idx_mess_is_less & ~idx_mess_is_greater & ~idx_mess_is_float).value_counts()
res = (idx_mess_is_less | idx_mess_is_greater | idx_mess_is_float).value_counts()
res
# Out:
# messergebnis_c
# True    3671913
# Name: count, dtype: int64

# %% [markdown]
# ## Convert measurement results to float. Fill the limit column.

# %%
# %time df_qual.loc[idx_mess_is_float,"messergebnis_num"] = df_qual.loc[idx_mess_is_float,"messergebnis_c"].astype(float)
# %time df_qual.loc[idx_mess_is_float,"grenze"] = "="

# %time df_qual.loc[idx_mess_is_less,"messergebnis_num"] = df_qual.loc[idx_mess_is_less,"messergebnis_c"].str[1:].astype(float)
# %time df_qual.loc[idx_mess_is_less,"grenze"] = "<"

# %time df_qual.loc[idx_mess_is_greater,"messergebnis_num"] = df_qual.loc[idx_mess_is_greater,"messergebnis_c"].str[1:].astype(float)
# %time df_qual.loc[idx_mess_is_greater,"grenze"] = ">"
# Out:
# CPU times: total: 312 ms
# Wall time: 321 ms
# CPU times: total: 203 ms
# Wall time: 221 ms
# CPU times: total: 391 ms
# Wall time: 587 ms
# CPU times: total: 46.9 ms
# Wall time: 24 ms
# CPU times: total: 0 ns
# Wall time: 6.01 ms
# CPU times: total: 0 ns
# Wall time: 4.01 ms

# %%
print("Different values for column 'grenze'")
print(df_qual["grenze"].value_counts())
# Out:
# Different values for column 'grenze'
# grenze
# <    1974713
# =    1697167
# >         33
# Name: count, dtype: int64

# %%
df_qual[idx_mess_is_greater][["messergebnis_c", "messergebnis_num", "grenze"]].head()
# Out:
#          messergebnis_c  messergebnis_num grenze
# sl_nr
# 17552890       >1.00000           1.00000      >
# 1263499        >0.03875           0.03875      >
# 2016179        >1.00000           1.00000      >
# 2923020        >1.00000           1.00000      >
# 2923130        >1.00000           1.00000      >

# %%
df_qual[idx_mess_is_less][["messergebnis_c", "messergebnis_num", "grenze"]].head()
# Out:
#          messergebnis_c  messergebnis_num grenze
# sl_nr
# 17716627       <1.00000             1.000      <
# 17716638       <0.01000             0.010      <
# 17716639       <0.03000             0.030      <
# 17716670       <0.00200             0.002      <
# 17716672       <1.00000             1.000      <

# %%
df_qual[idx_mess_is_float][["messergebnis_c", "messergebnis_num", "grenze"]].head()
# Out:
#         messergebnis_c  messergebnis_num grenze
# sl_nr
# 2903561       22.00000              22.0      =
# 2903564        6.80000               6.8      =
# 2903565       12.80000              12.8      =
# 2903584       12.30000              12.3      =
# 2903585        7.40000               7.4      =

# %%
df_qual[df_qual["messergebnis_num"]<0]
# Out:
#          messstelle_id        pna_id   datum_pn  stoff_nr    probengut  \
# sl_nr
# 2937027      219278519  1/2005/90634 2005-11-16      1072  Grundwasser
# 2943925      219278519  1/2007/90357 2007-02-07      1015  Grundwasser
# 2976241      219278519  1/2007/90832 2007-07-23      1072  Grundwasser
# 2980420       59620419   5/2007/4322 2007-10-11      1072  Grundwasser
# 3006262       59160135   5/2007/4395 2007-10-16      1072  Grundwasser
# ...                ...           ...        ...       ...          ...
# 2868501       59540643   5/2005/1064 2005-02-23      1015  Grundwasser
# 2868904       59540485   5/2005/1135 2005-03-02      1015  Grundwasser
# 2869927       59160100   5/2005/1767 2005-04-12      1072  Grundwasser
# 2873380       59160056   5/2005/1636 2005-04-08      1072  Grundwasser
# 2878340       59620419   5/2005/3821 2005-09-05      1072  Grundwasser
#
#         messergebnis_c messergebnis_hinweis  bestimmungsgrenze masseinheit  \
# sl_nr
# 2937027      -60.00000                  NaN                NaN          mV
# 2943925       -0.90000                  NaN                NaN          °C
# 2976241      -11.00000                  NaN                NaN          mV
# 2980420      -27.00000                  NaN                NaN          mV
# 3006262       -5.00000                  NaN                NaN          mV
# ...                ...                  ...                ...         ...
# 2868501       -5.00000                  NaN                NaN          °C
# 2868904       -1.00000                  NaN                NaN          °C
# 2869927       -4.00000                  NaN                NaN          mV
# 2873380       -3.00000                  NaN                NaN          mV
# 2878340       -3.00000                  NaN                NaN          mV
#
#             trennverfahren                   verfahren vor_ort    herkunft  \
# sl_nr
# 2937027  Nach Laborjournal                         NaN           HYGC_BR-K
# 2943925  Nach Laborjournal  DIN 38404-C4 DEZEMBER 1976      ja   HYGC_BR-K
# 2976241  Nach Laborjournal                         NaN           HYGC_BR-K
# 2980420       Gesamtgehalt       DIN 38404-C6 MAI 1984          HYGC_BR-AR
# 3006262       Gesamtgehalt       DIN 38404-C6 MAI 1984          HYGC_BR-AR
# ...                    ...                         ...     ...         ...
# 2868501       Gesamtgehalt  DIN 38404-C4 DEZEMBER 1976          HYGC_BR-AR
# 2868904       Gesamtgehalt  DIN 38404-C4 DEZEMBER 1976          HYGC_BR-AR
# 2869927       Gesamtgehalt       DIN 38404-C6 MAI 1984          HYGC_BR-AR
# 2873380       Gesamtgehalt       DIN 38404-C6 MAI 1984          HYGC_BR-AR
# 2878340       Gesamtgehalt       DIN 38404-C6 MAI 1984          HYGC_BR-AR
#
#         aktual_dat erstell_dat  messergebnis_num grenze
# sl_nr
# 2937027 2006-01-30  2006-01-30             -60.0      =
# 2943925 2007-08-20  2007-08-20              -0.9      =
# 2976241 2007-10-29  2007-10-29             -11.0      =
# 2980420 2007-11-07  2007-11-07             -27.0      =
# 3006262 2008-02-26  2008-02-26              -5.0      =
# ...            ...         ...               ...    ...
# 2868501 2005-04-07  2005-04-07              -5.0      =
# 2868904 2005-04-07  2005-04-07              -1.0      =
# 2869927 2005-05-06  2005-05-06              -4.0      =
# 2873380 2005-07-21  2005-07-21              -3.0      =
# 2878340 2005-10-06  2005-10-06              -3.0      =
#
# [3666 rows x 17 columns]

# %% [markdown]
# ## Upload the data to the database with `df.to_sql()`

# %%
import sqlalchemy
engine = sqlalchemy.create_engine("postgresql+psycopg2://env_master:M123xyz@localhost/env_db")

# %%
# the default to_sql() / sqlalchemy method using psycopg2 (default PG driver) ...
# on my laptop:
# Approx. Wall time: 4min 32s 

# %time df_qual.to_sql(con=engine, name="gw_meas", schema="gw", if_exists="fail")
#%time df_qual.to_sql(con=engine, name="gw_meas", schema="gw", if_exists="replace")
# Out:
# CPU times: total: 3min 7s
# Wall time: 4min 57s
# 913

# %% [markdown]
# ## Search for duplicates! Primary key is not straight forward!

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
print("Connect")
# %sql postgresql://env_master:M123xyz@localhost/env_db
# Out:
# Connect

# %%
# %%sql
# alter table gw.gw_meas add constraint pk_gw_meas primary key (messstelle_id, datum_pn, stoff_nr)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# (psycopg2.errors.UniqueViolation) could not create unique index "pk_gw_meas"
# DETAIL:  Key (messstelle_id, datum_pn, stoff_nr)=(110040200, 2005-10-04 00:00:00, 1061) is duplicated.
# CONTEXT:  parallel worker
#
# [SQL: alter table gw.gw_meas add constraint pk_gw_meas primary key (messstelle_id, datum_pn, stoff_nr)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from gw.gw_meas where (messstelle_id, datum_pn, stoff_nr) = (73537317, '1990-08-17 00:00:00', 1061)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 2 rows affected.
# [(5165938, 73537317, '7/1990/2850', datetime.datetime(1990, 8, 17, 0, 0), 1061, 'Grundwasser', '6.90000', None, None, '-', 'Gesamtgehalt', 'DIN 38404-C5 JANUAR 1984', 'ja', 'HYGC_BR-K', datetime.datetime(1994, 12, 1, 0, 0), datetime.datetime(1994, 12, 1, 0, 0), 6.9, '='),
#  (5165937, 73537317, '7/1990/2850', datetime.datetime(1990, 8, 17, 0, 0), 1061, 'Grundwasser', '7.20000', None, None, '-', 'Gesamtgehalt', 'DEV C5-2 4.LIEFERUNG 1966', ' ', 'HYGC_BR-K', datetime.datetime(1994, 12, 1, 0, 0), datetime.datetime(1994, 12, 1, 0, 0), 7.2, '=')]

# %%
# %%sql
# select * from gw.gw_meas where (messstelle_id, datum_pn, stoff_nr) = (119009997, '1995-05-16 00:00:00', 1082)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 2 rows affected.
# [(9029994, 119009997, '11/1995/60101', datetime.datetime(1995, 5, 16, 0, 0), 1082, 'Grundwasser', '78.00000', None, None, 'mS/m', 'Gesamtgehalt', 'DIN 38404-C8 09.85;DIN EN 27888 11.1993', ' ', 'HYGC_BR-MS', datetime.datetime(1996, 10, 11, 0, 0), datetime.datetime(1996, 10, 11, 0, 0), 78.0, '='),
#  (9029993, 119009997, '11/1995/60101', datetime.datetime(1995, 5, 16, 0, 0), 1082, 'Grundwasser', '77.00000', None, None, 'mS/m', 'Gesamtgehalt', 'DIN 38404-C8 SEPTEMBER 1982', ' ', 'HYGC_BR-MS', datetime.datetime(1996, 10, 11, 0, 0), datetime.datetime(1996, 10, 11, 0, 0), 77.0, '=')]

# %%
# %%sql
# select sl_nr,count(sl_nr) as count from gw.gw_meas group by sl_nr having count(sl_nr) > 1;
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 0 rows affected.
# []

# %%
# %%sql
# alter table gw.gw_meas add constraint pk_gw_meas primary key (sl_nr)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %% [markdown]
# ## Create some indexes to improve database performance

# %%
# %%sql
# create index idx_gw_meas_messstelle_id_datum_pn on gw.gw_meas (messstelle_id, datum_pn)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# create index idx_gw_meas_datum_pn_meas_messstelle on gw.gw_meas (datum_pn, messstelle_id)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# create index idx_gw_meas_stoff_nr on gw.gw_meas (stoff_nr)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# create index idx_gw_meas_datum_pn_stoff_nr on gw.gw_meas (datum_pn, stoff_nr);
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%time
# %sql select count(*) from gw.gw_meas
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 1 rows affected.
# CPU times: total: 0 ns
# Wall time: 254 ms
# [(3671913,)]

# %%
# %%time
# %sql select messstelle_id, datum_pn, count(*) as count from gw.gw_meas group by (messstelle_id, datum_pn) limit 20
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 20 rows affected.
# CPU times: total: 0 ns
# Wall time: 6.01 ms
# [(10131310, datetime.datetime(1984, 5, 17, 0, 0), 17),
#  (10131310, datetime.datetime(1984, 11, 23, 0, 0), 20),
#  (10131310, datetime.datetime(1985, 4, 26, 0, 0), 22),
#  (10131310, datetime.datetime(1988, 9, 21, 0, 0), 25),
#  (10131310, datetime.datetime(1989, 9, 20, 0, 0), 25),
#  (10131310, datetime.datetime(1991, 11, 22, 0, 0), 36),
#  (10131310, datetime.datetime(1992, 10, 14, 0, 0), 37),
#  (10131310, datetime.datetime(1993, 11, 12, 0, 0), 44),
#  (10131310, datetime.datetime(1994, 11, 29, 0, 0), 46),
#  (10131310, datetime.datetime(1995, 9, 12, 0, 0), 36),
#  (10131310, datetime.datetime(1996, 10, 21, 0, 0), 48),
#  (10131310, datetime.datetime(1997, 4, 3, 0, 0), 46),
#  (10131310, datetime.datetime(1997, 10, 16, 0, 0), 48),
#  (10131310, datetime.datetime(1998, 7, 2, 0, 0), 46),
#  (10131310, datetime.datetime(1999, 3, 18, 0, 0), 47),
#  (10131310, datetime.datetime(2000, 2, 23, 0, 0), 47),
#  (10131310, datetime.datetime(2001, 3, 13, 0, 0), 47),
#  (10131310, datetime.datetime(2002, 3, 13, 0, 0), 46),
#  (10131310, datetime.datetime(2003, 4, 10, 0, 0), 45),
#  (10131310, datetime.datetime(2004, 1, 7, 0, 0), 46)]

# %% [markdown]
# # Import `katalog_stoff`

# %%
katalog_stoff_path = 'C:\\Users\\demid\\Desktop\\GeoInfo_WS2023_2_Final_D\\data\\original\\katalog_stoff.csv'

# %%
df_katalog_stoff = pd.read_csv(katalog_stoff_path, sep=';')

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://env_master:M123xyz@localhost/env_db")

# %%
df_katalog_stoff.to_sql(name='katalog_stoff', con=engine, schema='gw', if_exists='replace', index=False)
# Out:
# 966

# %%
# %%sql
# SELECT * FROM gw.katalog_stoff WHERE name LIKE 'N%'
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 60 rows affected.
# [(1105, 'Neodym', None, '7440-00-8'),
#  (1112, 'Natrium', None, '7440-23-5'),
#  (1143, 'Niob', None, '7440-03-1'),
#  (1188, 'Nickel', None, '7440-02-0'),
#  (1244, 'Nitrat', None, None),
#  (1245, 'Nitrat-Stickstoff', None, None),
#  (1246, 'Nitrit', None, None),
#  (1247, 'Nitrit-Stickstoff', None, None),
#  (1567, 'Nichtionische Tenside', None, None),
#  (2035, 'N,N-Dimethylformamid', None, '68-12-2'),
#  (2036, 'N,N-Dibutylformamid', None, '761-65-9'),
#  (2090, 'Nitrobenzol', None, '98-95-3'),
#  (2228, 'Norflurazon', None, '27314-13-2'),
#  (2277, 'Neburon', None, '555-37-3'),
#  (2305, 'Naphthalin', None, '91-20-3'),
#  (2322, 'Napropamid', None, '15299-99-7'),
#  (2365, 'Nitrofen', None, '1836-75-5'),
#  (2506, 'N-Ethylanilin', None, '103-69-5'),
#  (2507, 'N,N-Diethylanilin', None, '91-66-7'),
#  (2509, 'N-Methylanilin', None, '100-61-8'),
#  (2510, 'N,N-Dimethylanilin', None, '121-69-7'),
#  (2568, 'N,N-Dimethyl-4-pyridinamin', None, '1122-58-3'),
#  (2600, 'Nitrilotriessigsäure (NTA)', None, '139-13-9'),
#  (2617, 'N-Methyl-N-octyl-1-octanamin', None, '4455-26-9'),
#  (2618, 'Nonan', None, '111-84-2'),
#  (2641, 'Naproxen', None, '22204-53-1'),
#  (2657, 'Nadolol', None, '42200-33-9'),
#  (2788, 'Nicosulfuron', None, '111991-09-4'),
#  (2837, 'N-Phenyl-2-naphthylamin', None, '135-88-6'),
#  (2874, 'Nitromethan', None, '75-52-5'),
#  (2888, 'Nonylphenol', None, '25154-52-3'),
#  (2894, 'Nonylphenolethoxylate', None, None),
#  (2926, 'Nafcillin', None, '147-52-4'),
#  (4000, 'N,N-Dimethylsulfamid', None, '3984-14-3'),
#  (4058, 'Nonylphenolmonoethoxylat', None, '104-35-8'),
#  (4059, 'Nonylphenoldiethoxylat', None, '20427-84-3'),
#  (4081, 'N-Nitroso-Dimethylamin', None, '62-75-9'),
#  (4119, 'Naled', None, '300-76-5'),
#  (4138, 'N-Acetyl-Sulfamethoxazol', None, '21312-10-7'),
#  (4171, 'Natriumcyclamat', None, '139-05-9'),
#  (4184, 'Niclosamid', None, '50-65-7'),
#  (4198, 'Nitenpyram', None, '150824-47-8'),
#  (4289, 'Norfloxacin', None, '70458-96-7'),
#  (4349, 'N-Guanylharnstoff', None, '141-83-3'),
#  (4351, 'N-Desethylvardenafil', None, '448184-46-1'),
#  (4437, 'Nevirapin', None, '129618-40-2'),
#  (4457, 'N,N-Didesvenlafaxin', None, '93413-77-5'),
#  (4458, 'N4-Acetylsulfadiazin', None, '127-74-2'),
#  (4459, 'N-Desvenlafaxin', None, '149289-30-5'),
#  (4460, 'N-Ethylperfluoroctansulfonamid', None, '4151-50-2'),
#  (4461, 'N-Methylperfluoroctansulfonamid', None, '31506-32-8'),
#  (4462, 'N-Nitrosodibutylamin', None, '924-16-3'),
#  (4463, 'N-Nitrosodiethylamin', None, '55-18-5'),
#  (4464, 'N-Nitrosodipropylamin', None, '621-64-7'),
#  (4465, 'N-Nitrosomethylethylamin', None, '10595-95-6'),
#  (4466, 'N-Nitrosomorpholin', None, '59-89-2'),
#  (4467, 'N-Nitrosopiperidin', None, '100-75-4'),
#  (4468, 'N-Nitrosopyrrolidin', None, '930-55-2'),
#  (4505, 'Nicosulfuron Metabolit ASDM', None, '112006-75-4'),
#  (4506, 'Nicosulfuron Metabolit AUSN', None, '2307738-55-0')]

# %%
# %%sql
# alter table gw.katalog_stoff add constraint pk_katalog_stoff primary key (stoff_nr)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# create index idx_kat_stoff_name on gw.katalog_stoff (name)
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# select * from gw.gw_stations limit 3
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 3 rows affected.
# [(10000008, 70796, 'P3-BSR/Mariaschacht P 5 neu', '3068xx', '56254xx', 1.0, ' ', '05334032', None, None, None, None, 'GW-Beschaffenheit               ', '01.07.2016', '282_11', '01.07.2016', '282_11', 'RWÜ (Messstelle f. GWÜ geeignet)', 'monatlich', 'nein', 'nein', 'nein', 'ja', 'ja', 'nein', 'nein', 'GW-Messstelle                   ', 'keine Angabe', '-', '-', 'BSR Schotterwerk                                  ', 'Enwor GmbH                                        ', 700.0, None, 80.0, None, 1570.0, 21053.0, 20353.0, 100, 306850.0, 5625450.0, '0101000020E86400000000000088BA1241000000809A755541'),
#  (10000010, 1, 'SCHERPENSEEL NR 1  ', '2935xx', '56452xx', 1.0, 'privat', '05370028', ' 6D', 'Neurather Sand', None, None, 'LGD                             ', '01.07.2016', '28_04', '01.07.2016', '28_04', 'Grundwassergüteüberwachung', 'Messstelle besteht nicht mehr', 'ja', 'ja', 'nein', 'ja', 'ja', 'nein', 'nein', 'GW-Messstelle                   ', 'keine Angabe', '-', '-', 'Land NRW                                          ', 'keine Angabe                                      ', 400.0, None, 100.0, None, 4936.0, 7731.0, 7331.0, 100, 293550.0, 5645250.0, '0101000020E864000000000000B8EA114100000080F0885541'),
#  (10000021, 2, 'Bellinghoven Nr. 2 ', '312776', '5660432', 1.0, 'privat', '05370004', '14', 'Ältere Hauptterrassen', None, None, 'LGD                             ', '01.07.2016', '286_07', '01.07.2016', '286_07', None, 'Messstelle inaktiv', 'ja', 'nein', 'ja', 'ja', 'nein', 'nein', 'nein', 'Schachtbrunnen                  ', None, None, '-', 'keine Angabe                                      ', 'keine Angabe                                      ', None, None, 1000.0, None, 1411.0, 7885.0, 7885.0, 1, 312776.0, 5660432.0, '0101000020E8640000000000002017134100000000C4975541')]

# %% [markdown]
# # Create Views!

# %%
# %%sql
# create view gw.v_gw_stations_wrrl_chemie as
# select * from gw.gw_stations
# where im_wrrl_messnetz_chemie = 'ja'
# and freigabe_chemie = 'ja'
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# select count(*) from gw.v_gw_stations_wrrl_chemie
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 1 rows affected.
# [(1501,)]

# %%
# %%sql
# select geometry, messstelle_id, name, genau, im_wrrl_messnetz_chemie, im_wrrl_messnetz_wasserstand from gw.gw_stations
# limit 10
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 10 rows affected.
# [('0101000020E86400000000000088BA1241000000809A755541', 10000008, 'P3-BSR/Mariaschacht P 5 neu', 100, 'nein', 'nein'),
#  ('0101000020E864000000000000B8EA114100000080F0885541', 10000010, 'SCHERPENSEEL NR 1  ', 100, 'nein', 'nein'),
#  ('0101000020E8640000000000002017134100000000C4975541', 10000021, 'Bellinghoven Nr. 2 ', 1, 'nein', 'nein'),
#  ('0101000020E864000000000000A8BD124100000080BB955541', 10000033, 'Doveren Nr. 3      ', 100, 'nein', 'nein'),
#  ('0101000020E8640000000000001C461241000000C0288E5541', 10000045, 'Geilenkirchen Nr. 5', 1, 'nein', 'nein'),
#  ('0101000020E8640000000000005890124100000080A7905541', 10000057, 'Lindern Nr. 6      ', 100, 'nein', 'nein'),
#  ('0101000020E8640000000000000CB51241000000C0AF865541', 10000069, 'Dürboslar Nr. 8    ', 1, 'nein', 'nein'),
#  ('0101000020E864000000000000904D134100000000E0895541', 10000070, 'Freiwald Nr. 9     ', 1, 'nein', 'nein'),
#  ('0101000020E864000000000000E8041241000000C0B8825541', 10000082, 'HERZOGENRATH Nr.10 ', 1, 'nein', 'ja'),
#  ('0101000020E86400000000000010E01141000000008F7C5541', 10000094, 'Richterich Nr. 11  ', 1, 'nein', 'nein')]

# %%
# %%sql
# select *
# from gw.gw_meas
# limit 1
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 1 rows affected.
# [(8525887, 100746410, '10/1987/60025', datetime.datetime(1987, 12, 3, 0, 0), 1138, 'Grundwasser', '<5.00000', 'Konzentration zu gering zur Bestimmung', None, 'µg/l', 'Gesamtgehalt', None, ' ', 'HYGC_BR-DET', datetime.datetime(1997, 5, 14, 0, 0), datetime.datetime(1997, 5, 14, 0, 0), 5.0, '<')]

# %%
# %%sql
# select sl_nr, messstelle_id, stoff_nr, datum_pn, grenze, messergebnis_num, masseinheit
# from gw.gw_meas
# limit 3
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 3 rows affected.
# [(8525887, 100746410, 1138, datetime.datetime(1987, 12, 3, 0, 0), '<', 5.0, 'µg/l'),
#  (8526299, 106502475, 1249, datetime.datetime(1997, 3, 20, 0, 0), '<', 0.0155, 'mg/l'),
#  (8526295, 106502475, 1171, datetime.datetime(1997, 3, 20, 0, 0), '<', 0.01, 'mg/l')]

# %%
# %%sql
# select
# st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.messstelle_id = m.messstelle_id
# and m.stoff_nr = p.stoff_nr
# limit 2
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 2 rows affected.
# [('0101000020E864000000000000B8ED1D410000008095F75541', 100746410, 'LHEID BR HEIDEN LAG', 100, 'ja', 'nein', 8525887, 1138, 'Blei', datetime.datetime(1987, 12, 3, 0, 0), '<', 5.0, 'µg/l'),
#  ('0101000020E864000000000000F8D41E410000008041055641', 106502475, 'ALMEN BR ALMENA    ', 100, 'ja', 'nein', 8526299, 1249, 'Ammonium-Stickstoff', datetime.datetime(1997, 3, 20, 0, 0), '<', 0.0155, 'mg/l')]

# %%
# %%sql
# create or replace view gw.gw_station_series as
# select
# m.sl_nr as fid, st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.messstelle_id = m.messstelle_id
# and m.stoff_nr = p.stoff_nr
# order by messstelle_id, stoff_nr, datum_pn
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# select * from gw.katalog_stoff where name = 'Nitrat'
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 1 rows affected.
# [(1244, 'Nitrat', None, None)]

# %%
# %%sql
# select distinct (im_wrrl_messnetz_chemie) from gw.gw_stations
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 2 rows affected.
# [('nein',), ('ja',)]

# %%
# %%sql
# create or replace view gw.v_gw_station_nitrat as
# select
# m.sl_nr as fid, st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.im_wrrl_messnetz_chemie = 'ja'
# and p.name = 'Nitrat'
# and m.stoff_nr = p.stoff_nr
# and st.messstelle_id = m.messstelle_id
# order by messstelle_id, stoff_nr, datum_pn
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %%sql
# create or replace view gw.v_gw_station_sulfat as
# select
# m.sl_nr as fid, st.geometry, st.messstelle_id, st.name, st.genau, st.im_wrrl_messnetz_chemie, st.im_wrrl_messnetz_wasserstand,
# m.sl_nr, m.stoff_nr,  p.name as stoffname, m.datum_pn, m.grenze, m.messergebnis_num, m.masseinheit
# from gw.gw_stations st, gw.gw_meas m, gw.katalog_stoff p
# where st.im_wrrl_messnetz_chemie = 'ja'
# and p.name = 'Sulfat'
# and m.stoff_nr = p.stoff_nr
# and st.messstelle_id = m.messstelle_id
# order by messstelle_id, stoff_nr, datum_pn
# Out:
#  * postgresql://env_master:***@localhost/env_db
# Done.
# []

# %%
# %sql select count(*) from gw.v_gw_station_sulfat
# Out:
#  * postgresql://env_master:***@localhost/env_db
# 1 rows affected.
# [(56527,)]
